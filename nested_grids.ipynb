# %%
import yt

# %%
ds1 = yt.load("Box0-L3/RD0002/RedshiftOutput0002")
# Out:
# yt : [INFO     ] 2021-07-07 13:33:03,792 Parameters: current_time              = 22.374633700269
# yt : [INFO     ] 2021-07-07 13:33:03,793 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-07 13:33:03,794 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-07 13:33:03,795 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-07 13:33:03,796 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-07 13:33:03,796 Parameters: current_redshift          = 10
# yt : [INFO     ] 2021-07-07 13:33:03,797 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-07 13:33:03,798 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-07 13:33:03,799 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-07 13:33:03,801 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds1,"x","all_density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-07 13:33:44,850 Projection completed
# yt : [INFO     ] 2021-07-07 13:33:44,851 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:44,851 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:44,853 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:44,853 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:44,855 Making a fixed resolution buffer of (('deposit', 'all_density')) 800 by 800
# yt : [WARNING  ] 2021-07-07 13:33:45,207 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:45,215 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:45,221 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:45,229 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:45,238 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds1,"x","all_density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-07 13:33:59,442 Projection completed
# yt : [INFO     ] 2021-07-07 13:33:59,443 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:59,444 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:59,445 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:59,446 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:33:59,448 Making a fixed resolution buffer of (('deposit', 'all_density')) 800 by 800
# yt : [WARNING  ] 2021-07-07 13:33:59,793 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:59,800 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:59,808 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:59,816 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:33:59,824 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds1,"z","all_density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-07 13:34:07,409 Projection completed
# yt : [INFO     ] 2021-07-07 13:34:07,410 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:34:07,410 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:34:07,412 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:34:07,412 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:34:07,414 Making a fixed resolution buffer of (('deposit', 'all_density')) 800 by 800
# yt : [WARNING  ] 2021-07-07 13:34:07,732 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:34:07,739 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:34:07,748 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:34:07,755 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:34:07,763 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...
