# %%
import yt

# %%
ds1 = yt.load("Box0-L3-R0/DD0017/data0017")
# Out:
# yt : [INFO     ] 2021-07-16 00:03:37,439 Parameters: current_time              = 7.1659484706477
# yt : [INFO     ] 2021-07-16 00:03:37,440 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-16 00:03:37,441 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-16 00:03:37,442 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-16 00:03:37,444 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-16 00:03:37,445 Parameters: current_redshift          = 22.502725227242
# yt : [INFO     ] 2021-07-16 00:03:37,446 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-16 00:03:37,447 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-16 00:03:37,448 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-16 00:03:37,449 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds1,"x","density")
# Out:
# Parsing Hierarchy : 100%|█████████████████| 3377/3377 [00:00<00:00, 7228.04it/s]
# yt : [INFO     ] 2021-07-16 00:03:43,314 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2021-07-16 00:03:46,792 Projection completed
# yt : [INFO     ] 2021-07-16 00:03:46,793 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:03:46,794 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:03:46,795 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:03:46,796 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:03:46,798 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.ProjectionPlot(ds1,"y","density")
# Out:
# yt : [INFO     ] 2021-07-16 00:04:28,173 Projection completed
# yt : [INFO     ] 2021-07-16 00:04:28,174 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:04:28,174 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:04:28,176 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:04:28,177 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:04:28,183 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.ProjectionPlot(ds1,"z","density")
# Out:
# yt : [INFO     ] 2021-07-16 00:01:02,923 Projection completed
# yt : [INFO     ] 2021-07-16 00:01:02,924 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:01:02,924 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:01:02,926 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:01:02,928 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:01:02,929 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:01:03,456 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,513 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,558 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,603 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,646 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,694 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,744 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,792 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:01:03,837 Supplied id_loc but draw_ids is False. Not drawing grid ids
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds1 = yt.load("Box0-L3-R1/DD0043/data0043")
# Out:
# yt : [ERROR    ] 2021-07-16 00:01:50,387 Couldn't figure out output type for Box0-L3-R1/DD0043/data0043
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# /var/folders/54/bwgsrg4n39bc0mn5z1jryg6h0000gn/T/ipykernel_29596/2975239440.py in <module>
# ----> 1 ds1 = yt.load("Box0-L3-R1/DD0043/data0043")
#
# /usr/local/lib/python3.8/site-packages/yt/convenience.py in load(*args, **kwargs)
#      96                 return output_type_registry[n](fn)
#      97         mylog.error("Couldn't figure out output type for %s", args[0])
# ---> 98         raise YTOutputNotIdentified(args, kwargs)
#      99
#     100     mylog.error("Multiple output type candidates for %s:", args[0])
#
# YTOutputNotIdentified: Supplied ('Box0-L3-R1/DD0043/data0043',) {}, but could not load!

# %%
yt.ProjectionPlot(ds2,"x","density")

# %%
yt.ProjectionPlot(ds2,"y","density")

# %%
yt.ProjectionPlot(ds2,"z","density")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/54/bwgsrg4n39bc0mn5z1jryg6h0000gn/T/ipykernel_29596/4246372722.py in <module>
# ----> 1 yt.ProjectionPlot(ds2,"z","density")
#
# NameError: name 'ds2' is not defined
