# %%
import yt

# %%
ds1 = yt.load("Box0-L3-R0/DD0017/data0017")
# Out:
# yt : [INFO     ] 2021-07-16 00:19:19,345 Parameters: current_time              = 7.1659484706477
# yt : [INFO     ] 2021-07-16 00:19:19,346 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-16 00:19:19,347 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-16 00:19:19,348 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-16 00:19:19,349 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-16 00:19:19,350 Parameters: current_redshift          = 22.502725227242
# yt : [INFO     ] 2021-07-16 00:19:19,351 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-16 00:19:19,351 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-16 00:19:19,352 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-16 00:19:19,353 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds1,"x","density")
# Out:
# Parsing Hierarchy : 100%|█████████████████| 3377/3377 [00:00<00:00, 9964.09it/s]
# yt : [INFO     ] 2021-07-16 00:19:22,778 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2021-07-16 00:19:26,104 Projection completed
# yt : [INFO     ] 2021-07-16 00:19:26,105 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:26,105 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:26,107 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:26,108 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:26,110 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.ProjectionPlot(ds1,"y","density")
# Out:
# yt : [INFO     ] 2021-07-16 00:19:30,462 Projection completed
# yt : [INFO     ] 2021-07-16 00:19:30,463 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:30,464 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:30,466 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:30,467 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:30,468 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.ProjectionPlot(ds1,"z","density")
# Out:
# yt : [INFO     ] 2021-07-16 00:20:36,974 Projection completed
# yt : [INFO     ] 2021-07-16 00:20:36,975 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:36,976 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:36,977 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:36,978 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:36,980 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds2 = yt.load("Box0-L3-R1/DD0043/data0043")
# Out:
# yt : [INFO     ] 2021-07-16 00:20:40,235 Parameters: current_time              = 18.086012641084
# yt : [INFO     ] 2021-07-16 00:20:40,236 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-16 00:20:40,237 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-16 00:20:40,238 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-16 00:20:40,239 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-16 00:20:40,240 Parameters: current_redshift          = 11.677357391944
# yt : [INFO     ] 2021-07-16 00:20:40,241 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-16 00:20:40,242 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-16 00:20:40,244 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-16 00:20:40,245 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds2,"x","density")
# Out:
# Parsing Hierarchy : 100%|█████████████████| 8205/8205 [00:01<00:00, 5478.54it/s]
# yt : [INFO     ] 2021-07-16 00:20:44,463 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2021-07-16 00:20:50,128 Projection completed
# yt : [INFO     ] 2021-07-16 00:20:50,129 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:50,129 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:50,131 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:50,132 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:20:50,133 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.ProjectionPlot(ds2,"y","density")
# Out:
# yt : [INFO     ] 2021-07-16 00:19:55,564 Projection completed
# yt : [INFO     ] 2021-07-16 00:19:55,565 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:55,565 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:55,567 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:55,568 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:55,570 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
yt.ProjectionPlot(ds2,"z","density")
# Out:
# yt : [INFO     ] 2021-07-16 00:19:51,447 Projection completed
# yt : [INFO     ] 2021-07-16 00:19:51,448 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:51,449 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:51,450 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:51,451 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:51,453 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
