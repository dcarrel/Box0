# %%
import yt

# %%
ds = yt.load("Box0-L3-gas/RD0002/RedshiftOutput0002")
# Out:
# yt : [INFO     ] 2021-07-07 13:35:08,328 Parameters: current_time              = 22.374633700269
# yt : [INFO     ] 2021-07-07 13:35:08,329 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-07 13:35:08,329 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-07 13:35:08,330 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-07 13:35:08,332 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-07 13:35:08,333 Parameters: current_redshift          = 10
# yt : [INFO     ] 2021-07-07 13:35:08,333 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-07 13:35:08,335 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-07 13:35:08,335 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-07 13:35:08,336 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds,"x","density").annotate_grids()
# Out:
# Parsing Hierarchy : 100%|███████████████████| 222/222 [00:00<00:00, 7854.24it/s]
# yt : [INFO     ] 2021-07-07 13:35:27,353 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2021-07-07 13:35:29,213 Projection completed
# yt : [INFO     ] 2021-07-07 13:35:29,223 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:29,224 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:29,225 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:29,226 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:29,238 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-07 13:35:30,185 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:30,193 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:30,202 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds,"y","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-07 13:35:42,880 Projection completed
# yt : [INFO     ] 2021-07-07 13:35:42,881 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:42,882 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:42,883 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:42,884 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:42,886 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-07 13:35:43,204 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:43,216 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:43,225 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:43,231 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:43,241 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds,"z","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-07 13:35:51,972 Projection completed
# yt : [INFO     ] 2021-07-07 13:35:51,973 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:51,974 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:51,975 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:51,976 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-07 13:35:51,978 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-07 13:35:52,297 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:52,306 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:52,313 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:52,323 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-07 13:35:52,330 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...
