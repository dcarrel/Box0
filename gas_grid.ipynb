# %%
import yt

# %%
ds1 = yt.load("Box0-L3-R0/DD0017/data0017")
# Out:
# yt : [INFO     ] 2021-07-16 00:19:15,549 Parameters: current_time              = 7.1659484706477
# yt : [INFO     ] 2021-07-16 00:19:15,550 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-16 00:19:15,551 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-16 00:19:15,552 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-16 00:19:15,553 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-16 00:19:15,553 Parameters: current_redshift          = 22.502725227242
# yt : [INFO     ] 2021-07-16 00:19:15,554 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-16 00:19:15,555 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-16 00:19:15,556 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-16 00:19:15,557 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds1,"x","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-16 00:19:14,195 Projection completed
# yt : [INFO     ] 2021-07-16 00:19:14,196 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:14,196 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:14,198 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:14,199 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:19:14,200 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:19:14,713 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:19:14,763 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:19:14,813 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:19:14,859 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:19:14,905 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds1,"y","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-16 00:13:44,246 Projection completed
# yt : [INFO     ] 2021-07-16 00:13:44,247 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:44,247 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:44,249 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:44,250 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:44,251 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:13:44,777 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:44,824 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:44,868 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:44,912 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:44,955 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds1,"y","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-16 00:13:47,317 Projection completed
# yt : [INFO     ] 2021-07-16 00:13:47,318 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:47,319 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:47,320 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:47,321 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:13:47,323 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:13:47,928 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:47,973 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:48,017 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:48,062 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:13:48,105 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
ds2 = yt.load("Box0-L3-R1/DD0043/data0043")
# Out:
# yt : [INFO     ] 2021-07-16 00:14:24,202 Parameters: current_time              = 18.086012641084
# yt : [INFO     ] 2021-07-16 00:14:24,202 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-16 00:14:24,203 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-16 00:14:24,204 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-16 00:14:24,205 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-16 00:14:24,206 Parameters: current_redshift          = 11.677357391944
# yt : [INFO     ] 2021-07-16 00:14:24,206 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-16 00:14:24,207 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-16 00:14:24,208 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-16 00:14:24,209 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds2,"x","density").annotate_grids()
# Out:
# Parsing Hierarchy : 100%|█████████████████| 8205/8205 [00:01<00:00, 8074.58it/s]
# yt : [INFO     ] 2021-07-16 00:14:27,126 Gathering a field list (this may take a moment.)
# yt : [INFO     ] 2021-07-16 00:14:33,245 Projection completed
# yt : [INFO     ] 2021-07-16 00:14:33,246 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:33,246 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:33,248 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:33,249 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:33,250 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:14:34,243 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:34,315 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:34,387 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds2,"y","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-16 00:14:39,114 Projection completed
# yt : [INFO     ] 2021-07-16 00:14:39,115 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:39,116 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:39,117 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:39,119 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:39,120 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:14:39,887 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:39,962 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:40,038 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:40,114 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:40,186 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds2,"z","density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-16 00:14:44,727 Projection completed
# yt : [INFO     ] 2021-07-16 00:14:44,728 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:44,729 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:44,731 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:44,732 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-16 00:14:44,733 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [WARNING  ] 2021-07-16 00:14:45,481 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:45,554 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:45,630 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:45,709 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-16 00:14:45,788 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...
