# %%
import yt

# %%
ds = yt.load("Box0-L2/RD0002/RedshiftOutput0002")
# Out:
# yt : [INFO     ] 2021-07-06 10:37:04,933 Parameters: current_time              = 22.374633700269
# yt : [INFO     ] 2021-07-06 10:37:04,933 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2021-07-06 10:37:04,934 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-06 10:37:04,935 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2021-07-06 10:37:04,936 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2021-07-06 10:37:04,937 Parameters: current_redshift          = 10
# yt : [INFO     ] 2021-07-06 10:37:04,938 Parameters: omega_lambda              = 0.685
# yt : [INFO     ] 2021-07-06 10:37:04,938 Parameters: omega_matter              = 0.315
# yt : [INFO     ] 2021-07-06 10:37:04,939 Parameters: omega_radiation           = 0
# yt : [INFO     ] 2021-07-06 10:37:04,940 Parameters: hubble_constant           = 0.674

# %%
yt.ProjectionPlot(ds,"x","all_density").annotate_
# Out:
# yt : [INFO     ] 2021-07-06 10:37:29,421 Projection completed
# yt : [INFO     ] 2021-07-06 10:37:29,422 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:29,423 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:29,424 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:29,425 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:29,427 Making a fixed resolution buffer of (('deposit', 'all_density')) 800 by 800
# yt : [WARNING  ] 2021-07-06 10:37:29,750 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:29,755 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:29,760 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:29,766 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:29,772 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds,"y","all_density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-06 10:37:44,171 Projection completed
# yt : [INFO     ] 2021-07-06 10:37:44,172 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:44,173 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:44,174 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:44,175 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:44,176 Making a fixed resolution buffer of (('deposit', 'all_density')) 800 by 800
# yt : [WARNING  ] 2021-07-06 10:37:44,575 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:44,579 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:44,584 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:44,593 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:44,598 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...

# %%
yt.ProjectionPlot(ds,"z","all_density").annotate_grids()
# Out:
# yt : [INFO     ] 2021-07-06 10:37:54,917 Projection completed
# yt : [INFO     ] 2021-07-06 10:37:54,918 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:54,919 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:54,921 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:54,921 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-06 10:37:54,923 Making a fixed resolution buffer of (('deposit', 'all_density')) 800 by 800
# yt : [WARNING  ] 2021-07-06 10:37:55,229 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:55,235 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:55,239 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:55,245 Supplied id_loc but draw_ids is False. Not drawing grid ids
# yt : [WARNING  ] 2021-07-06 10:37:55,251 Supplied id_loc but draw_ids is False. Not drawing grid ids
# ...
